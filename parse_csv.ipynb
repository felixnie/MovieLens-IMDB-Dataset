# %%
import ast
import pandas as pd
import pickle
import numpy as np


def parse_list(x):
    try:
        return ast.literal_eval(x)
    except (SyntaxError, ValueError):
        return x

# %% [markdown]
# # ml_1m_imdb

# %%
# pickle -> csv

# with open('ml_1m_imdb.pickle', 'rb') as f:
#     df = pickle.load(f)

# df.to_csv('ml_1m_imdb.csv', index=False)

df = pd.read_csv('ml_1m_imdb.csv')

df
# Out:
#       ml_id    imdb_id                            ml_title  \
# 0         1  tt0114709                    Toy Story (1995)
# 1         2  tt0113497                      Jumanji (1995)
# 2         3  tt0113228             Grumpier Old Men (1995)
# 3         4  tt0114885            Waiting to Exhale (1995)
# 4         5  tt0113041  Father of the Bride Part II (1995)
# ...     ...        ...                                 ...
# 3878   3948  tt0212338             Meet the Parents (2000)
# 3879   3949  tt0180093          Requiem for a Dream (2000)
# 3880   3950  tt0170691                    Tigerland (2000)
# 3881   3951  tt0202641             Two Family House (2000)
# 3882   3952  tt0208874               Contender, The (2000)
#
#                        imdb_title ml_year imdb_year  \
# 0                       Toy Story    1995      1995
# 1                         Jumanji    1995      1995
# 2                Grumpier Old Men    1995      1995
# ...

# %% [markdown]
# # ml_100k_imdb

# %%
# pickle -> csv

# with open('ml_100k_imdb.pickle', 'rb') as f:
#     df = pickle.load(f)

# df.to_csv('ml_100k_imdb.csv', index=False)

df = pd.read_csv('ml_100k_imdb.csv')

df
# Out:
#       ml_id    imdb_id                                   ml_title  \
# 0         1  tt0114709                           Toy Story (1995)
# 1         2  tt0113189                           GoldenEye (1995)
# 2         3  tt0113101                          Four Rooms (1995)
# 3         4  tt0113161                          Get Shorty (1995)
# 4         5  tt0112722                             Copycat (1995)
# ...     ...        ...                                        ...
# 1677   1678  tt0119711                          Mat' i syn (1997)
# 1678   1679  tt0120594                           B. Monkey (1998)
# 1679   1680  tt0120148                       Sliding Doors (1998)
# 1680   1681  tt0111804                        You So Crazy (1994)
# 1681   1682  tt0102855  Scream of Stone (Schrei aus Stein) (1991)
#
#                          imdb_title  ml_year  imdb_year  \
# 0                         Toy Story   1995.0     1995.0
# 1                         GoldenEye   1995.0     1995.0
# ...
